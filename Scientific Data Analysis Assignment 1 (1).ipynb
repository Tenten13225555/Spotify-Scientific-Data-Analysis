# %% [markdown]
# Student Number: 100755953
# Name: Amartei Brocke
# Title of Project: Top Spotify Hits (2000 - 2019)

# %% [markdown]
# # Top Spotify Hits  <font color='green'> (2000 - 2019)</font>
#
# ### Understanding how music elements relate to popularity. (Introduction)

# %% [markdown]
# Spotify is a digital music streaming service that provides users access to over 82 million songs, podcasts and audio books. The app was developed by Daniel Ek and Martin Lorenzton in 2006. This app has become a family name over the years and boasts over 457 million subscribers as of 2022, rivaling SoundCloud and Apple Music.
#
# Spotify measures the popularity of its' artists based on their monthly listeners and number of streams they receive on songs produced. These streams are then multipled by (0.003) and paid to artists as "Royalties", it is a modernized system of monetizing digital sales from traditional album sales (100 streams = 1 album). Ed Sheeran was Spotify's most streamed artist in 2019, however, the rank placements change rapidly depending on album relases, EP's, mixtapes and so forth!
#
# Spotify is a perfect dataset to measure the popularity of songs against various music elements, across a large set of songs throughout the decades. This analysis can be used to demonstrate how peoples music tastes have been translated throughout the past two decades!

# %% [markdown]
# <p align="center">
# <img src="spotify.png"  align="center" width="600" height="340">
# </p>

# %% [markdown]
# # Column Descriptions

# %% [markdown]
# (Written by the Dataset Creator, the paragraph properly defines the datasets' columns and has been placed here for comprehension)

# %% [markdown]
# Artist: The artists' names who performed the track. If there is more than one artist, they are separated by a ;
#
# Song: Name of the track
#
# Year: Year the song was released
#
# Popularity: The popularity of a track is a value between 0 and 100, with 100 being the most popular. The popularity is calculated by algorithm and is based, in the most part, on the total number of plays the track has had and how recent those plays are. Generally speaking, songs that are being played a lot now will have a higher popularity than songs that were played a lot in the past. Duplicate tracks (e.g. the same track from a single and an album) are rated independently. Artist and album popularity is derived mathematically from track popularity.
#
# Explicit : Whether or not the track has explicit lyrics (true = yes it does; false = no it does not OR unknown)
#
# Danceability: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable
#
# Energy: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale
# key: The key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1
#
# Loudness: The overall loudness of a track in decibels (dB)
#
# Speechiness: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks
#
# Acousticness: A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic
#
# Instrumentalness: Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content
#
# Liveness: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live
#
#
# Tempo: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration
#
#
# Track Genre: The genre in which the track belongs

# %% [markdown]
# ## Data Loading

# %% [markdown]
# A subset of data obtained about popular music tracks obtained from Kaggle.com, a public open-source website for information.

# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
spotify = pd.read_csv("songs_normalize.csv")

spotify
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# The spotify dataset needs cleaning as it contains columns that provide no analytical value, have improper naming and do not have enough relevance to the goal of the overall project. Furthermore, normalizing the significant values across the DataFrame to maintain consistency.

# %%
# Setting the precision of floating numbers  
pd.set_option('display.precision', 3) 

display(spotify)
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
# Dropping unecessary columns 
spotify2=spotify.drop(columns=["duration_ms", "mode", "liveness"], axis = 1)
display(spotify2)
# Out:
#               artist                                    song  explicit  year  \
# 0     Britney Spears                  Oops!...I Did It Again     False  2000
# 1          blink-182                    All The Small Things     False  1999
# 2         Faith Hill                                 Breathe     False  1999
# 3           Bon Jovi                            It's My Life     False  2000
# 4             *NSYNC                             Bye Bye Bye     False  2000
# ...              ...                                     ...       ...   ...
# 1995  Jonas Brothers                                  Sucker     False  2019
# 1996    Taylor Swift                            Cruel Summer     False  2019
# 1997    Blanco Brown                              The Git Up     False  2019
# 1998       Sam Smith  Dancing With A Stranger (with Normani)     False  2019
# 1999     Post Malone                                 Circles     False  2019
#
# ...

# %%
#Formatting the column names
spotify2.columns.values[0:] =["Artist", "Song", "Explicit", "Year", "Popularity", "Danceability", "Energy", "Key","Loudness", "Speechiness", "Acousticness","Instrumentalness", "Valence", "Tempo", "Genre" ]
spotify2
# Out:
#               Artist                                    Song  Explicit  Year  \
# 0     Britney Spears                  Oops!...I Did It Again     False  2000
# 1          blink-182                    All The Small Things     False  1999
# 2         Faith Hill                                 Breathe     False  1999
# 3           Bon Jovi                            It's My Life     False  2000
# 4             *NSYNC                             Bye Bye Bye     False  2000
# ...              ...                                     ...       ...   ...
# 1995  Jonas Brothers                                  Sucker     False  2019
# 1996    Taylor Swift                            Cruel Summer     False  2019
# 1997    Blanco Brown                              The Git Up     False  2019
# 1998       Sam Smith  Dancing With A Stranger (with Normani)     False  2019
# 1999     Post Malone                                 Circles     False  2019
#
# ...

# %%
# Changing explicit

spotify3 = pd.DataFrame(spotify2) 

spotify2.loc[spotify2["explicit"] == "True", "explicit"] = 1 

spotify2.loc[spotify2["explicit"] == "False", "explicit"] = 0  

spotify2
# Out:
#               Artist                                    Song Explicit  Year  \
# 0     Britney Spears                  Oops!...I Did It Again    False  2000
# 1          blink-182                    All The Small Things    False  1999
# 2         Faith Hill                                 Breathe    False  1999
# 3           Bon Jovi                            It's My Life    False  2000
# 4             *NSYNC                             Bye Bye Bye    False  2000
# ...              ...                                     ...      ...   ...
# 1995  Jonas Brothers                                  Sucker    False  2019
# 1996    Taylor Swift                            Cruel Summer    False  2019
# 1997    Blanco Brown                              The Git Up    False  2019
# 1998       Sam Smith  Dancing With A Stranger (with Normani)    False  2019
# 1999     Post Malone                                 Circles    False  2019
#
# ...

# %%
# Ensuring there are no Nan values
spotify2 = spotify2.dropna(axis=0)

spotify2
# Out:
#               Artist                                    Song Explicit  Year  \
# 0     Britney Spears                  Oops!...I Did It Again    False  2000
# 1          blink-182                    All The Small Things    False  1999
# 2         Faith Hill                                 Breathe    False  1999
# 3           Bon Jovi                            It's My Life    False  2000
# 4             *NSYNC                             Bye Bye Bye    False  2000
# ...              ...                                     ...      ...   ...
# 1995  Jonas Brothers                                  Sucker    False  2019
# 1996    Taylor Swift                            Cruel Summer    False  2019
# 1997    Blanco Brown                              The Git Up    False  2019
# 1998       Sam Smith  Dancing With A Stranger (with Normani)    False  2019
# 1999     Post Malone                                 Circles    False  2019
#
# ...

# %% [markdown]
# This shows that the dataset is complete and requires no cleaning in terms of Nan values.

# %% [markdown]
# # Exploratory Analyses

# %% [markdown]
# As of now, I will be exploring popularity of music within the dataset and how it correlates to other musical elements.
#
# 1. Is there a correlation between popularity and energy?
# 2. Which genre has the most Hit songs from 2000-2019?
# 3. Is explicit music or non-explicit music more popular?

# %% [markdown]
# ## Data Manipulation

# %%
"""1. Is there a correlation between popularity and energy?
I will be attempting to observe the relationship between populariity and energy, to do this I will do the following:
- Access and pull out the popularity and energy columns 
- Create a scatterplot to best represent the information between the popularity and energy data
- Utilise 'Pearson's Coefficient' to determing the strength of the correlation between the variables."""

spotify3=spotify2.groupby('popularity')['energy'].mean().sort_values(ascending=[False]).reset_index()
spotify3.head()
# Out:
#    Popularity  Energy
# 0          38   0.919
# 1          24   0.872
# 2          34   0.861
# 3          17   0.861
# 4          37   0.814

# %% [markdown]
# ## Generated Plot

# %%
# Create a scatterplot to visualize the data
popularity = spotify3.loc[:,"Popularity"]
energy = spotify3.loc[:,"Energy"]
plt.scatter(popularity, energy, c="green")
plt.title("Correlation between Popularity and Energy", fontsize=18, y=1.03)
plt.xlabel("Popularity", fontsize=14, labelpad=15)
plt.ylabel("Energy", fontsize=14, labelpad=15)
plt.show()

# %%
pearsonnum = spotify3.corr(method='pearson')

pearsonnum
# Out:
#             Popularity  Energy
# Popularity       1.000  -0.039
# Energy          -0.039   1.000

# %% [markdown]
# Therefore based on the Pearson coefficient value, -0.039, there is a weak negtive relationship between the popularity and energy variables

# %% [markdown]
# ## Data Manipulation

# %%
"""2. Which genre has the most Hit songs from 2000-2019?"""
spotify2_genre=spotify2[spotify2["genre"]!='[]']
spotify2_genre.head()
# Out:
#            Artist                    Song Explicit  Year  Popularity  \
# 0  Britney Spears  Oops!...I Did It Again    False  2000          77
# 1       blink-182    All The Small Things    False  1999          79
# 2      Faith Hill                 Breathe    False  1999          66
# 3        Bon Jovi            It's My Life    False  2000          78
# 4          *NSYNC             Bye Bye Bye    False  2000          65
#
#    Danceability  Energy  Key  Loudness  Speechiness  Acousticness  \
# 0         0.751   0.834    1    -5.444        0.044         0.300
# 1         0.434   0.897    0    -4.918        0.049         0.010
# 2         0.529   0.496    7    -9.007        0.029         0.173
# 3         0.551   0.913    0    -4.063        0.047         0.026
# 4         0.614   0.928    8    -4.806        0.052         0.041
#
#    Instrumentalness  Valence    Tempo         Genre
# 0         1.770e-05    0.894   95.053           pop
# ...

# %%
splitgenres=pd.DataFrame(spotify2_genre.assign(genre=spotify2_genre.genre.str.split(",")).explode('genre'))

splitgenres.tail()
# Out:
#       Artist  Song  Explicit  Year  Popularity  Danceability  Energy  Key  \
# 1996     NaN   NaN       NaN   NaN         NaN           NaN     NaN  NaN
# 1997     NaN   NaN       NaN   NaN         NaN           NaN     NaN  NaN
# 1997     NaN   NaN       NaN   NaN         NaN           NaN     NaN  NaN
# 1998     NaN   NaN       NaN   NaN         NaN           NaN     NaN  NaN
# 1999     NaN   NaN       NaN   NaN         NaN           NaN     NaN  NaN
#
#       Loudness  Speechiness  Acousticness  Instrumentalness  Valence  Tempo  \
# 1996       NaN          NaN           NaN               NaN      NaN    NaN
# 1997       NaN          NaN           NaN               NaN      NaN    NaN
# 1997       NaN          NaN           NaN               NaN      NaN    NaN
# 1998       NaN          NaN           NaN               NaN      NaN    NaN
# 1999       NaN          NaN           NaN               NaN      NaN    NaN
#
#          Genre
# 1996       pop
# 1997   hip hop
# ...

# %%
numcount = 9

top10=pd.DataFrame(splitgenres['Genre'].value_counts()[:numcount]).reset_index()

top10.rename(columns = {'index':'Genre','count':'Total'}, inplace = True)

top10
# Out:
#                Genre  Genre
# 0                pop    936
# 1            hip hop    776
# 2                pop    697
# 3                R&B    439
# 4   Dance/Electronic    349
# 5               rock    162
# 6               rock     72
# 7              metal     57
# 8              latin     49

# %%
top6final = top10.drop(index=([2,5,8]))

top6final
# Out:
#                Genre  Genre
# 0                pop    936
# 1            hip hop    776
# 3                R&B    439
# 4   Dance/Electronic    349
# 6               rock     72
# 7              metal     57

# %%
top6final.columns = ['Genre', 'Count']

top6final
# Out:
#                Genre  Count
# 0                pop    936
# 1            hip hop    776
# 3                R&B    439
# 4   Dance/Electronic    349
# 6               rock     72
# 7              metal     57

# %% [markdown]
# ## Generated Plot

# %%
Genre = top6final.loc[:,"Genre"]
Count = top6final.loc[:,"Count"]
popularity = spotify3.loc[:,"Popularity"]

plt.bar(Genre, Count, color="green")


plt.title("Distribution of Hit Songs by Genre", fontsize=12, y=1.03)
plt.xlabel("Genre", fontsize=14, labelpad=15)
plt.ylabel("Count", fontsize=14, labelpad=15)
plt.show()

# %% [markdown]
# ## Data Manipulation and Generated Plot

# %% [markdown]
# Therefore, pop music has the most hits from (2000 - 2019)

# %%
"""Is explicit music or non-explicit music more popular?"""


spotify2['explicit'].value_counts().plot(kind='barh', color = 'black', ylabel='Explicit music', fontsize = 10, title = 'Distribution of Explicit Music vs Non-Explicit Music')
# Out:
# <AxesSubplot:title={'center':'Distribution of Explicit Music vs Non-Explicit Music'}, ylabel='Explicit music'>

# %% [markdown]
# This shows that there is a significantly higher amount of hit songs without explicit lyrics(majority) than with explicit lyrics

# %% [markdown]
# # Discussion

# %% [markdown]
# In this assignment, I analyzed data from the prominent app Spotify and attempted to relate hit songs to music elements. I investigated three main things throughout this analysis:
#
# 1. Is there a correlation between popularity and energy? - Observed tthe relationship between popularity and energy.
# 2. 2. Which genre has the most Hit songs from 2000-2019? - Observed the genre distribution across the dataset to determine what genre has the most hit songs.
# 3. Is explicit music or non-explicit music more popular? -  Observed the explicit distribution across the datset, to evaluate if explicit or non-explicit music is more popular in hit songs.
#
# - Firstly, by separating the desired columns and graphing, I was able to calculate Pearson's Coefficient that would presnt me with a significance between the two variables. From my results, I obtained a -0.39 and can deduce that there is a negative weak relationship Energy and Popularity.
#
# - Secondly, by "exploding" the genre column I obtained a way to properly analyze its distribution ross the dataset. I then focused on the top 6 for a more concise and streamlined analysis. Afterwards, I graphed the data and was able to determine that most hit songs from 2000 - 2019 are from the "Pop" Genre.
#
# -  Thirdly, the explicit lyrics were accounted for. I measured it across the distribution and I graphed the data and was able to determine that there is signficantly more music that is Non-Explicit (79% - Non Explicit, 21% - Explicit).
#
# Although, there were various other musical elements to examine, I decided to take a non-traditional approach and look at musical elements that are usually overlooked.
#
# Overall, Spotify is an excellent high-quality mobile application that connects millions of users to their favourite musical work!

# %% [markdown]
# <p align="center">
# <img src="GettyImages_1140668438_green.0.jpg"  align="center" width="600" height="340">
# </p>

# %% [markdown]
# # References

# %% [markdown]
# Source data - https://www.kaggle.com/datasets/paradisejoy/top-hits-spotify-from-20002019
#
# Image data - spotify.png, GettyImages_1140668438_green.0.jpg
# 1. Pandas for data manipulation and data viz
# 2. Matplotlib for data manipuation and data viz
# 3. Numpy for data manipulation
# 4. Seaborn for data manipulation
